# %% [markdown]
# # Average performance of best performing hyperparameters for each algorithm in Case 1

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
from matplotlib.pyplot import gca
from matplotlib.ticker import FormatStrFormatter
import seaborn as sns


import os
dirs = [x[0] for x in os.walk("./Case1/")]
dirs=dirs[1:]
# print(dirs[1:])


seed_list = [0, 1, 2, 3, 4]
n_steps = 250


########### On policy results ###############################
algo_list = [ "PPO", "TRPO"]
batch_list_best = [32000, 8000]
color = ['green', 'purple']

for i, algo in enumerate(algo_list):
    batch = batch_list_best[i]
    df_list = []
    for j, seed in enumerate(seed_list):
        fname = ("./Case1/log_"+str(algo)+"_3d-tracking_id-"+str(batch)+"-0.98_"+str(seed)+"_tanh_64_64") 
        print(fname)
        if fname in dirs:
            print('yep')
            dirs.remove(fname)

########### Off policy results ###############################
algo_list = ["DDPG", "SAC", "TD3"]
batch_list_best = [2000000, 2000000, 2000000]
color = ['darkorange', 'red', 'blue']

for i, algo in enumerate(algo_list):
    batch = batch_list_best[i]
    df_list = []
    for j, seed in enumerate(seed_list):
        fname = ("./Case1/log_"+str(algo)+"_3d-tracking_buffer-v4_id-"+str(batch)+"-0.98_"+str(seed)+"_tanh_64_64") 
        if fname in dirs:
            print('yep')
            dirs.remove(fname)
# Out:
# ./Case1/log_PPO_3d-tracking_id-32000-0.98_0_tanh_64_64
# yep
# ./Case1/log_PPO_3d-tracking_id-32000-0.98_1_tanh_64_64
# yep
# ./Case1/log_PPO_3d-tracking_id-32000-0.98_2_tanh_64_64
# yep
# ./Case1/log_PPO_3d-tracking_id-32000-0.98_3_tanh_64_64
# yep
# ./Case1/log_PPO_3d-tracking_id-32000-0.98_4_tanh_64_64
# yep
# ./Case1/log_TRPO_3d-tracking_id-8000-0.98_0_tanh_64_64
# yep
# ./Case1/log_TRPO_3d-tracking_id-8000-0.98_1_tanh_64_64
# yep
# ./Case1/log_TRPO_3d-tracking_id-8000-0.98_2_tanh_64_64
# yep
# ./Case1/log_TRPO_3d-tracking_id-8000-0.98_3_tanh_64_64
# yep
# ./Case1/log_TRPO_3d-tracking_id-8000-0.98_4_tanh_64_64
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep

# %% [markdown]
# # Average results for different batchsizes (On Policy Algorithm)

# %%
n_steps = 250
seed_list = [0, 1, 2, 3, 4]

f=0

batch_list = [1000, 2000, 4000, 8000, 16000, 32000, 64000, 128000]
algo_list = [ "PPO", "TRPO"]
color = ['red', 'blue', 'green', 'orange', 'purple', '#1b9e77', '#66a61e', 'slateblue']
label = ['(a)','(b)']

for k, algo in enumerate(algo_list):
    plt.subplot(1,2,f+1)
    f+=1
    for i, batch in enumerate(batch_list):
        df_list = []
        for j, seed in enumerate(seed_list):
            fname = ("./Case1/log_"+str(algo)+"_3d-tracking_id-"+str(batch)+"-0.98_"+str(seed)+"_tanh_64_64")  
            if fname in dirs:
                print('yep')
                dirs.remove(fname)
# Out:
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep

# %% [markdown]
# # Average results for different replay buffer sizes (Off Policy Algorithm)

# %%
n_steps=250
seed_list = [0, 1, 2, 3, 4]

f=0

algo_list = ["SAC", "TD3","DDPG"]
batch_list = [100000, 200000, 500000, 1000000, 2000000]
color = ['red', 'blue', 'green', 'orange', 'purple', '#1b9e77', '#66a61e', 'darkgrey']
label = ['(a)','(b)','(c)']

for k, algo in enumerate(algo_list):
    plt.subplot(1,3,f+1)
    f+=1
    for i, batch in enumerate(batch_list):
        df_list = []
        for j, seed in enumerate(seed_list):
            fname = ("./Case1/log_"+str(algo)+"_3d-tracking_buffer_id-"+str(batch)+"-0.98_"+str(seed)+"_tanh_64_64") 
            if fname in dirs:
                print('yep')
                dirs.remove(fname)
# Out:
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep
# yep

# %%
print(dirs)
# Out:
# ['./Case1/log_DDPG_3d-tracking_id-10000-0.98_0_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-200-0.98_0_tanh_64_64', './Case1/log_TD3_3d-tracking_id-2000-0.98_2_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-20000-0.98_1_tanh_64_64', './Case1/log_TD3_3d-tracking_id-4000-0.98_1_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-100-0.98_0_tanh_64_64', './Case1/log_TD3_3d-tracking_id-500-0.98_1_tanh_64_64', './Case1/log_TD3_3d-tracking_id-32000-0.98_0_tanh_64_64', './Case1/log_TD3_3d-tracking_id-8000-0.98_2_tanh_64_64', './Case1/log_TD3_3d-tracking_id-1000-0.98_1_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-64000-0.98_1_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-8000-0.98_0_tanh_64_64', './Case1/log_TD3_3d-tracking_buffer-v4_id-500000-0.98_4_tanh_64_64', './Case1/log_TD3_3d-tracking_id-64000-0.98_0_tanh_64_64', './Case1/log_TD3_3d-tracking_id-200-0.98_1_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-0-0.98_0_tanh_64_64', './Case1/log_SAC_3d-tracking_id-50000-0.98_0_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-32000-0.98_1_tanh_64_64', './Case1/log_TD3_3d-tracking_id-16000-0.98_2_tanh_64_64', './Case1/log_TD3_3d-tracking_id-1.5-0.98_0_tanh_64_64', './Case1/log_TD3_3d-tracking_id-20000-0.98_0_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-5000-0.98_1_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-2000-0.98_0_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-128000-0.98_0_tanh_64_64', './Case1/log_TD3_3d-tracking_id-100-0.98_1_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-500-0.98_0_tanh_64_64', './Case1/log_TD3_3d-tracking_id-2000-0.98_0_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-200-0.98_2_tanh_64_64', './Case1/log_TD3_3d-tracking_buffer-v4_id-1000000-0.98_4_tanh_64_64', './Case1/log_SAC_3d-tracking_id-2000-0.98_0_tanh_64_64', './Case1/log_TD3_3d-tracking_id-8000-0.98_0_tanh_64_64', './Case1/log_SAC_3d-tracking_id-500-0.98_0_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-100-0.98_2_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-50000-0.98_0_tanh_64_64', './Case1/log_TD3_3d-tracking_id-32000-0.98_2_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-16000-0.98_1_tanh_64_64', './Case1/log_TD3_3d-tracking_id-16000-0.98_0_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-4000-0.98_1_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-1000-0.98_1_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-8000-0.98_2_tanh_64_64', './Case1/log_TD3_3d-tracking_id-64000-0.98_2_tanh_64_64', './Case1/log_SAC_3d-tracking_id-4096-0.98_0_tanh_64_64', './Case1/log_TD3_3d-tracking_id-128000-0.98_1_tanh_64_64', './Case1/log_SAC_3d-tracking_id-10000-0.98_0_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-500-0.98_2_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-128000-0.98_2_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-2000-0.98_2_tanh_64_64', './Case1/log_SAC_3d-tracking_id-100-0.98_0_tanh_64_64', './Case1/log_TD3_3d-tracking_id-200-0.98_0_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-1000-0.98_2_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-8000-0.98_1_tanh_64_64', './Case1/log_TD3_3d-tracking_id-64000-0.98_1_tanh_64_64', './Case1/log_SAC_3d-tracking_id-1-0.98_0_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-32000-0.98_0_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-4000-0.98_2_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-5000-0.98_0_tanh_64_64', './Case1/log_TD3_3d-tracking_id-10000-0.98_0_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-128000-0.98_1_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-2000-0.98_1_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-500-0.98_1_tanh_64_64', './Case1/log_TD3_3d-tracking_id-128000-0.98_2_tanh_64_64', './Case1/log_TD3_3d-tracking_id-100-0.98_0_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-200-0.98_1_tanh_64_64', './Case1/log_SAC_3d-tracking_id-0-0.98_0_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-10000-0.98_1_tanh_64_64', './Case1/log_TD3_3d-tracking_id-500-0.98_0_tanh_64_64', './Case1/log_SAC_3d-tracking_id-1000-0.98_0_tanh_64_64', './Case1/log_TD3_3d-tracking_id-32000-0.98_1_tanh_64_64', './Case1/log_DDPG_3d-tracking_id-16000-0.98_2_tanh_64_64', './ ...
